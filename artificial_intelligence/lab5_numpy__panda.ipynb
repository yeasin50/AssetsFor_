# %%
import pandas as pd
df = pd.read_csv("datasets/testbd.csv")

# %%
df
# Out:
#   name  age  weight
# 0    a    1      55
# 1    b    2      85
# 2    c    3      33
# 3    d    4      47

# %%
df["name"]
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# Name: name, dtype: object

# %%
df.axes[1]
# Out:
# Index(['name', 'age', 'weight'], dtype='object')

# %%
df.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df.plot(x="age",y="weight")
# Out:
# <AxesSubplot:xlabel='age'>

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df["age"],df["weight"])
plt.title("Scatter plot")
plt.xlabel("Age")
plt.ylabel("Weight")

plt.colorbar()

plt.show()
